# %% [markdown]
# # Optical Flow with Convolution Neural Networks

# %% [markdown]
# The paper's version of optical flow produces a vector <-x, +x, -y, +y, -z, +z>.
# Our result vector needs to change in track_object(frame1, frame2, x, y, w, h, steps) - currently the displacement should be `[x,y]`, so we'll just need to do some conditional wizardry and expand it out.

# %% [markdown]
# *NOTE:* Prior to running any of this, a virtual environment is needed. Once in the venv, run `pip install -r requirements.txt` to prepare all of the required libraries.

# %%
import numpy as np
flow = np.array([-2,3])
final_flow = np.array([0, 0, 0, 0, 0, 0])

if flow[0] < 0:
    final_flow[0] = abs(flow[0])
elif flow[0] > 0:
    final_flow[1] = abs(flow[0])

if flow[1] < 0:
    final_flow[2] = abs(flow[1])
elif flow[1] > 0:
    final_flow[3] = abs(flow[1])
final_flow
# Out:
# array([2, 0, 0, 3, 0, 0])

# %% [markdown]
# The videos used are all releaseed under the Creative Commons Attribution 3.0 license.
# We can generate the list of all files in the training directory (in this case, a scene from "Big Buck Bunny") as follows:

# %%
import os
file_list = os.listdir("bunny")

# %% [markdown]
# We'll need to add the directory name to the beginning of each file:

# %%
for x in range(len(file_list)):
    file_list[x] = 'bunny/' + file_list[x]

# %% [markdown]
# First off, let's look at a couple of optical flow examples.

# %%
from optical_flow import run_lk

flow_vector = run_lk(file_list[0], file_list[1], 124, 158, 254, 233, steps=5)
flow_vector
# Out:
# [0, 0.14430177, 0, 0.03125444, 0, 0]

# %% [markdown]
# We can track the same bounding box's movement in the next frame as well:

# %%
flow_vector = run_lk(file_list[1], file_list[2], 124-flow_vector[0]+flow_vector[1],
                                                 158-flow_vector[2]+flow_vector[3],
                                                 254, 233, steps=5)
flow_vector
# Out:
# [0, 0.11882825, 0, 0.48146176, 0, 0]

# %% [markdown]
# Preparing the dataset will use the `prepare_dataset` function in the `optical_flow.py` file. The signature for this function is:
# `prepare_dataset(files_list, result_file, x, y, w, h, steps=5)`
# The bounding box should be determined for the scene, and consists of the x,y,w,h parameters.

# %%
from optical_flow import prepare_dataset
prepare_dataset(file_list, "train-data.csv", 124, 158, 254, 233, steps=5)

# %% [markdown]
# To train and evaluate the neural net, we'll use the Lkvf file.

# %%
from Lkvf import train
history = train()
# Out:
# Using TensorFlow backend.
# Epoch 1/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.6889 - accuracy: 0.5839
# Epoch 2/100
# 149/149 [==============================] - 0s 411us/step - loss: 0.6834 - accuracy: 0.6779
# Epoch 3/100
# 149/149 [==============================] - 0s 379us/step - loss: 0.6784 - accuracy: 0.7192
# Epoch 4/100
# 149/149 [==============================] - 0s 383us/step - loss: 0.6746 - accuracy: 0.7483
# Epoch 5/100
# 149/149 [==============================] - 0s 387us/step - loss: 0.6706 - accuracy: 0.7998
# Epoch 6/100
# 149/149 [==============================] - 0s 356us/step - loss: 0.6646 - accuracy: 0.8255
# Epoch 7/100
# 149/149 [==============================] - 0s 367us/step - loss: 0.6622 - accuracy: 0.8356
# Epoch 8/100
# 149/149 [==============================] - 0s 357us/step - loss: 0.6571 - accuracy: 0.8568
# Epoch 9/100
# 149/149 [==============================] - 0s 375us/step - loss: 0.6532 - accuracy: 0.8904
# Epoch 10/100
# 149/149 [==============================] - 0s 347us/step - loss: 0.6485 - accuracy: 0.8803
# Epoch 11/100
# 149/149 [==============================] - 0s 349us/step - loss: 0.6433 - accuracy: 0.8982
# Epoch 12/100
# 149/149 [==============================] - 0s 375us/step - loss: 0.6401 - accuracy: 0.8881
# Epoch 13/100
# 149/149 [==============================] - 0s 424us/step - loss: 0.0578 - accuracy: 0.9832
# Epoch 79/100
# 149/149 [==============================] - 0s 412us/step - loss: 0.0657 - accuracy: 0.9832
# Epoch 80/100
# 149/149 [==============================] - 0s 440us/step - loss: 0.0548 - accuracy: 0.9821
# Epoch 81/100
# 149/149 [==============================] - 0s 444us/step - loss: 0.0589 - accuracy: 0.9821
# Epoch 82/100
# 149/149 [==============================] - 0s 397us/step - loss: 0.0454 - accuracy: 0.9888
# Epoch 83/100
# 149/149 [==============================] - 0s 398us/step - loss: 0.0368 - accuracy: 0.9911
# Epoch 84/100
# 149/149 [==============================] - 0s 387us/step - loss: 0.0360 - accuracy: 0.9911
# Epoch 85/100
# 149/149 [==============================] - 0s 382us/step - loss: 0.0553 - accuracy: 0.9799
# Epoch 86/100
# 149/149 [==============================] - 0s 393us/step - loss: 0.0430 - accuracy: 0.9888
# Epoch 87/100
# 149/149 [==============================] - 0s 405us/step - loss: 0.0485 - accuracy: 0.9855
# Epoch 88/100
# 149/149 [==============================] - 0s 406us/step - loss: 0.0417 - accuracy: 0.9888
# Epoch 89/100
# 149/149 [==============================] - 0s 397us/step - loss: 0.0395 - accuracy: 0.9933
# Epoch 90/100
# 149/149 [==============================] - 0s 378us/step - loss: 0.0382 - accuracy: 0.9899
# Epoch 91/100
# 149/149 [==============================] - 0s 396us/step - loss: 0.0304 - accuracy: 0.9911
# Epoch 92/100
# 149/149 [==============================] - 0s 377us/step - loss: 0.0428 - accuracy: 0.9888
# Epoch 93/100
# 149/149 [==============================] - 0s 392us/step - loss: 0.0282 - accuracy: 0.9922
# Epoch 94/100
# 149/149 [==============================] - 0s 405us/step - loss: 0.0482 - accuracy: 0.9866
# Epoch 95/100
# 149/149 [==============================] - 0s 371us/step - loss: 0.0515 - accuracy: 0.9843
# Epoch 96/100
# 149/149 [==============================] - 0s 394us/step - loss: 0.0371 - accuracy: 0.9911
# Epoch 97/100
# 149/149 [==============================] - 0s 492us/step - loss: 0.0309 - accuracy: 0.9966
# Epoch 98/100
# 149/149 [==============================] - 0s 429us/step - loss: 0.0278 - accuracy: 0.9899
# Epoch 99/100
# 149/149 [==============================] - 0s 415us/step - loss: 0.0341 - accuracy: 0.9911
# Epoch 100/100
# 149/149 [==============================] - 0s 408us/step - loss: 0.0379 - accuracy: 0.9944
# 149/149 [==============================] - 0s 461us/step
# 50/50 [==============================] - 0s 177us/step

# %% [markdown]
# Once we're trained up, we can check some visualizing through matplotlib to get an idea of our accuracy. This can be seen to approach very close to 100% accuracy, and finishes the training and evaluating loop with less than 1% loss.

# %%
from matplotlib import pyplot as plt


plt.plot(history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# And the loss factor in the model:

# %%
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# Running the new neural network on the correct bounding box for the first two frames gives the following results:

# %%
import imageio
from RunLKNN import LK, loadNN

x,y,w,h = 124, 158, 254, 233

first_frame = file_list[0]
second_frame = file_list[1]

LK((imageio.imread(first_frame)[
            :, :, :3].astype(np.float32) / 255.0)[y:y+h, x:x+w], (imageio.imread(second_frame)[
            :, :, :3].astype(np.float32) / 255.0)[y:y+h, x:x+w], loadNN('model.yaml', 'model.h5'))
# Out:
# Loaded model from disk
# [[1.0253765e-03 3.4895187e-04 6.7381986e-04 9.7792095e-04 2.7686681e-04
#   8.8575098e-06]]
# [-0.0006764246, 0.0003041011, -0.0002680093]
# [-0.0006764246, 0.0003041011, -0.0002680093]
